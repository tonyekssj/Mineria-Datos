# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('MEN_SHOES.csv')

# %%
data.shape
# Out:
# (23940, 5)

# %%
data.isnull().sum()
# Out:
# Brand_Name           0
# How_Many_Sold        0
# Current_Price      798
# Product_details      0
# RATING               0
# dtype: int64

# %%
data['Current_Price'] = data['Current_Price'].str.replace('₹', '')
data['Current_Price'] = data['Current_Price'].str.replace(',', '')
data['Current_Price'].unique()
data.dropna(axis = 0, inplace = True)
data['Current_Price'] = data['Current_Price'].astype(int)

data['How_Many_Sold'] = data['How_Many_Sold'].str.replace(',', '')
data['How_Many_Sold'].unique()
data.dropna(axis = 0, inplace = True)
data['How_Many_Sold'] = data['How_Many_Sold'].astype(int)

# %%
data.describe()
# Out:
#        How_Many_Sold  Current_Price       RATING
# count   23142.000000   23142.000000  23142.00000
# mean     3607.896552     842.258621      3.82069
# std     10896.836132     387.523381      0.40462
# min         2.000000     231.000000      2.40000
# 25%       173.000000     588.000000      3.60000
# 50%       406.500000     776.500000      4.00000
# 75%      1795.000000    1080.000000      4.00000
# max     72611.000000    2159.000000      4.40000

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = 'Brand_Name',
            y = 'RATING',            
            data = data).set(title = "Rating vs Brand Name");
plt.xticks(rotation = 90)
plt.show()

# %%
data.dtypes
# Out:
# Brand_Name          object
# How_Many_Sold        int32
# Current_Price        int32
# Product_details     object
# RATING             float64
# dtype: object

# %%
data = data.drop_duplicates()

colors = {'ASIAN': 'Blue',
          'Adidas': 'Red',
          'Axter': 'Green',
          'BATA': 'Yellow',
          'Bourge': 'Purple',
          'Campus': 'Orange',
          'Centrino': 'Pink',
          'Corstyle': 'Brown',
          'D Shoes': 'Cyan',
          'FEETEES': 'Magenta',
          'FURO': 'Teal',
          'Generic': 'Lime',
          'Kraasa': 'Gray',
          'Nivia': 'Olive',
          'Reebok': 'Maroon',
          'Robbie jones': 'Navy',
          'Sparx': 'Aqua',
          'URJO': 'Fuchsia',
          'Wakefield': 'Silver',
          'road runner': 'Black'
         }
brands_color = data.Brand_Name.map(colors)

# %%
fig, ax = plt.subplots()
for brands in set(data.Brand_Name):
    ax.scatter(
        data.RATING[data.Brand_Name == brands],
        data.Current_Price[data.Brand_Name == brands],
        s = 30,
        c = colors[brands],
        label = brands)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.xlabel("RATING")
plt.ylabel("Current_Prices")
plt.show()

# %%
sns.boxplot(x='Brand_Name', y='Current_Price', data=data)
plt.xticks(rotation=90)
plt.xlabel("Brand_Name",fontsize=14)
plt.ylabel("Current_Price",fontsize=14)
plt.show()

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#       Brand_Name  How_Many_Sold  Current_Price  \
# 0          ASIAN           2242           1098
# 1          ASIAN            240            674
# 2          ASIAN          16662            588
# 3          ASIAN            135            599
# 4         Reebok            240            982
# 6          ASIAN          72611            498
# 7        Generic             84            298
# 8          Sparx           1795            880
# 9        Generic            309            439
# 10        Reebok           2144           1005
# 11        Campus             12            780
# 12   road runner            421            499
# 13      Corstyle              7            579
# 14        Campus            245            702
# 15         Sparx             60           1279
# 16         Sparx            173           1199
# 18       D Shoes           1490            649
# 19        Kraasa           6159            399
# 20         ASIAN           7712            524
# ...

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = 'Brand_Name',
            y = 'RATING',
            data = datos).set(title = "Rating vs Brand Name");
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9884\871830249.py in <module>
#       2 sns.barplot(x = 'Brand_Name',
#       3             y = 'RATING',
# ----> 4             data = datos).set(title = "Rating vs Brand Name");
#       5 plt.xticks(rotation = 90)
#       6 plt.show()
#
# NameError: name 'datos' is not defined
